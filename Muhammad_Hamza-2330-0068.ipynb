# %% [markdown]
# - 2330-0068
# - Muhammad Hamza
# - Bs-AI

# %% [markdown]
# ## Task 1

# %%
# Out:
#   Cell In[1], line 11
#     ggplot(iris, aes(x = Sepal.Length)) +
#                                          ^
# SyntaxError: invalid syntax
